# %% [markdown]
# #### 电偶极子

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 直杆

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 圆环

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 圆盘

# %% [markdown]
# ![image.png](attachment:image.png)
